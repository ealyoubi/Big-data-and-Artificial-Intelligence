# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode

# %%
burritos_data = pd.read_csv('burritos.csv')

# %%
burritos_data
# Out:
#                      Location        Burrito       Date Neighborhood  \
# 0          Donato's taco shop    California   1/18/2016      Miramar
# 1        Oscar's Mexican food    California   1/24/2016   San Marcos
# 2        Oscar's Mexican food       Carnitas  1/24/2016          NaN
# 3        Oscar's Mexican food    Carne asada  1/24/2016          NaN
# 4                Pollos Maria     California  1/27/2016     Carlsbad
# ..                        ...            ...        ...          ...
# 418  Valentine's Mexican Food      Al Pastor  8/27/2019          NaN
# 419  Valentine's Mexican Food  Chile Relleno  8/27/2019          NaN
# 420  Valentine's Mexican Food     California  8/27/2019          NaN
# 421  Valentine's Mexican Food         Shrimp  8/27/2019          NaN
# 422  Valentine's Mexican Food    Pollo Asado  8/27/2019          NaN
#
#                       Address  \
# 0             6780 Miramar Rd
# 1    225 S Rancho Santa Fe Rd
# 2                         NaN
# ...

# %%
burritos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        423 non-null    object
#  1   Burrito         423 non-null    object
#  2   Date            423 non-null    object
#  3   Neighborhood    92 non-null     object
#  4   Address         88 non-null     object
#  5   URL             87 non-null     object
#  6   Yelp            87 non-null     float64
#  7   Google          87 non-null     float64
#  8   Chips           26 non-null     object
#  9   Cost            416 non-null    float64
#  10  Hunger          420 non-null    float64
#  11  Mass (g)        22 non-null     float64
#  12  Density (g/mL)  22 non-null     float64
#  13  Length          284 non-null    float64
#  14  Circum          282 non-null    float64
#  15  Volume          282 non-null    float64
#  16  Tortilla        423 non-null    float64
# ...

# %%
#1.bar chart of the distribution of values before handling NaN values
plt.figure(figsize=(10,5));
sns.barplot(y=burritos_data['Cost'], x=burritos_data['Google'])
plt.title("Burritos dataset")
# Out:
# Text(0.5, 1.0, 'Burritos dataset')

# %%
#2.Determine how many missing values are present in each column
#Method 1
def missingValues(a):
    return sum(a.isnull())
print(burritos_data.apply(missingValues , axis =0))
# Out:
# Location          0
# Burrito           0
# Date              0
# Neighborhood    331
# Address         335
#                ...
# Bacon           420
# Sushi           421
# Avocado         410
# Corn            420
# Zucchini        422
# Length: 66, dtype: int64

# %%
#Method 2
burritos_data.isnull().sum()
# Out:
# Location          0
# Burrito           0
# Date              0
# Neighborhood    331
# Address         335
#                ...
# Bacon           420
# Sushi           421
# Avocado         410
# Corn            420
# Zucchini        422
# Length: 66, dtype: int64

# %%
#Determine the total amount of missing values (count of missing values of the entire datafram)
burritos_data.isnull().sum().sum()
# Out:
# 18256

# %%
burritos_data.head()
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp  Google Chips  \
# 0                        http://donatostacoshop.net/   3.5     4.2   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3   NaN
# 2                                                NaN   NaN     NaN   NaN
# 3                                                NaN   NaN     NaN   NaN
# ...

# %%
#Choose a column and replace NaN values with the mean
#mode(burritos_data['Google']) # so 4.1 is the most frequent number and the count is 12
#burritos_data[np.isnan(burritos_data)] = np.nanmean(burritos_data)
burritos_data['Google'].fillna(np.mean(burritos_data['Google']),inplace = True)

# %%
burritos_data.isnull().sum().sum()
# Out:
# 17920

# %%
burritos_data.head()
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp    Google Chips  \
# 0                        http://donatostacoshop.net/   3.5  4.200000   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5  3.300000   NaN
# 2                                                NaN   NaN  4.167816   NaN
# 3                                                NaN   NaN  4.167816   NaN
# ...

# %%
#Choose a column and replace NaN values with the median
burritos_data['Cost'].fillna(np.median(burritos_data['Cost']),inplace = True)

# %%
burritos_data.head()
# Out:
#                Location      Burrito       Date Neighborhood  \
# 0    Donato's taco shop  California   1/18/2016      Miramar
# 1  Oscar's Mexican food  California   1/24/2016   San Marcos
# 2  Oscar's Mexican food     Carnitas  1/24/2016          NaN
# 3  Oscar's Mexican food  Carne asada  1/24/2016          NaN
# 4          Pollos Maria   California  1/27/2016     Carlsbad
#
#                     Address  \
# 0           6780 Miramar Rd
# 1  225 S Rancho Santa Fe Rd
# 2                       NaN
# 3                       NaN
# 4           3055 Harding St
#
#                                                  URL  Yelp    Google Chips  \
# 0                        http://donatostacoshop.net/   3.5  4.200000   NaN
# 1  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5  3.300000   NaN
# 2                                                NaN   NaN  4.167816   NaN
# 3                                                NaN   NaN  4.167816   NaN
# ...

# %%
#Choose a column and replace NaN values with the mode
burritos_data['URL'].fillna(mode(burritos_data['URL']).mode[0], inplace = True)

# %%
burritos_data.tail()
# Out:
#                      Location        Burrito       Date Neighborhood Address  \
# 418  Valentine's Mexican Food      Al Pastor  8/27/2019          NaN     NaN
# 419  Valentine's Mexican Food  Chile Relleno  8/27/2019          NaN     NaN
# 420  Valentine's Mexican Food     California  8/27/2019          NaN     NaN
# 421  Valentine's Mexican Food         Shrimp  8/27/2019          NaN     NaN
# 422  Valentine's Mexican Food    Pollo Asado  8/27/2019          NaN     NaN
#
#                                                    URL  Yelp    Google Chips  \
# 418  https://www.yelp.com/biz/el-dorado-mexican-foo...   NaN  4.167816   NaN
# 419  https://www.yelp.com/biz/el-dorado-mexican-foo...   NaN  4.167816   NaN
# 420  https://www.yelp.com/biz/el-dorado-mexican-foo...   NaN  4.167816   NaN
# 421  https://www.yelp.com/biz/el-dorado-mexican-foo...   NaN  4.167816   NaN
# 422  https://www.yelp.com/biz/el-dorado-mexican-foo...   NaN  4.167816   NaN
#
# ...

# %%
 #Choose a column and replace NaN values with your own value
#df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
burritos_data['Fish']=burritos_data['Fish'].fillna(0)

# %%
burritos_data.isnull().sum().sum()
# Out:
# 17167

# %%
# Choose a column and use backward filling
burritos_data['Address'].fillna(method= 'bfill')
# Out:
# 0               6780 Miramar Rd
# 1      225 S Rancho Santa Fe Rd
# 2               3055 Harding St
# 3               3055 Harding St
# 4               3055 Harding St
#                  ...
# 418                         NaN
# 419                         NaN
# 420                         NaN
# 421                         NaN
# 422                         NaN
# Name: Address, Length: 423, dtype: object

# %%
burritos_data.isnull().sum().sum()
# Out:
# 17167

# %%
# Choose a column and use forwards filling
burritos_data['Cost'].fillna(method= 'ffill')
# Out:
# 0      6.49
# 1      5.45
# 2      4.85
# 3      5.25
# 4      6.59
#        ...
# 418    6.00
# 419    6.00
# 420    7.90
# 421    7.90
# 422    5.50
# Name: Cost, Length: 423, dtype: float64

# %%
burritos_data
# Out:
#                      Location        Burrito       Date Neighborhood  \
# 0          Donato's taco shop    California   1/18/2016      Miramar
# 1        Oscar's Mexican food    California   1/24/2016   San Marcos
# 2        Oscar's Mexican food       Carnitas  1/24/2016          NaN
# 3        Oscar's Mexican food    Carne asada  1/24/2016          NaN
# 4                Pollos Maria     California  1/27/2016     Carlsbad
# ..                        ...            ...        ...          ...
# 418  Valentine's Mexican Food      Al Pastor  8/27/2019          NaN
# 419  Valentine's Mexican Food  Chile Relleno  8/27/2019          NaN
# 420  Valentine's Mexican Food     California  8/27/2019          NaN
# 421  Valentine's Mexican Food         Shrimp  8/27/2019          NaN
# 422  Valentine's Mexican Food    Pollo Asado  8/27/2019          NaN
#
#                       Address  \
# 0             6780 Miramar Rd
# 1    225 S Rancho Santa Fe Rd
# 2                         NaN
# ...

# %%
plt.figure(figsize=(10,5));
sns.barplot(y=burritos_data['Cost'], x=burritos_data['Google'])
plt.title("Burritos dataset")
# Out:
# Text(0.5, 1.0, 'Burritos dataset')

# %%
# The End
